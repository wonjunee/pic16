# %% [markdown]
# # PIC 16 - Discussion Week 8 Thursday Winter 2019

# %% [markdown]
# http://scikit-learn.org/stable/auto_examples/classification/plot_digits_classification.html

# %%
print(__doc__)

# Author: Gael Varoquaux <gael dot varoquaux at normalesup dot org>
# License: BSD 3 clause

# Standard scientific Python imports
import matplotlib.pyplot as plt
import numpy as np
import cv2

# Import datasets, classifiers and performance metrics
from sklearn import datasets, svm, metrics
# Out:
# Automatically created module for IPython interactive environment

# %%
# The digits dataset
digits = datasets.load_digits()

# The data that we are interested in is made of 8x8 images of digits, let's
# have a look at the first 4 images, stored in the `images` attribute of the
# dataset.  If we were working from image files, we could load them using
# matplotlib.pyplot.imread.  Note that each image must have the same size. For these
# images, we know which digit they represent: it is given in the 'target' of
# the dataset.

images = digits.images
target = digits.target

print "images shape:", images.shape
print "target shape:", target.shape
# Out:
# images shape: (1797, 8, 8)
# target shape: (1797,)

# %%
for i in range(20):
    plt.figure(figsize=(1, 2))
    plt.axis('off')
    plt.imshow(images[i], cmap=plt.cm.gray_r, interpolation='nearest')
    plt.title('Label: %i' % target[i])
    plt.show()

# %%
# To apply a classifier on this data, we need to flatten the image, to
# turn the data in a (samples, feature) matrix:
n_samples = len(images)
data = images.reshape((n_samples, -1))

print "data shape:", data.shape
# Out:
# data shape: (1797, 64)

# %% [markdown]
# # Problem
#
# Use **svm** to train the first half of the dataset.

# %%
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.001, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# # Problem
#
# Using the trained model from the above problem, calculate the accuracy of the model on the test dataset.
#
# The test dataset is the second half of the dataset.
